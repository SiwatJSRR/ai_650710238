# %% [markdown]
# <a href="https://colab.research.google.com/github/SiwatJSRR/ai_650710238/blob/main/client.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
url = 'https://21088a59b443.ngrok-free.app/predict'

# %%
data = {
    "age": 63,
    "sex": 1,
    "cp": 3,
    "trestbps": 145,
    "chol": 233,
    "fbs": 1,
    "restecg": 0,
    "thalach": 150,
    "exang": 0,
    "oldpeak": 2.3,
    "slope": 0,
    "ca": 0,
    "thal": 1
}

# %%
response = requests.post(url, json=data)

print(response.json())
# Out:
# {'prediction': 0}
